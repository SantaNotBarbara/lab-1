# %% [markdown]
# <a href="https://colab.research.google.com/github/SantaNotBarbara/lab-1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import numpy as np
i = Image.open("me.jpeg")
i.show()
import matplotlib.pyplot as plt
plt.imshow(np.asarray(i))
plt.show()

# %% [markdown]
# negative of an image

# %%
import cv2
import matplotlib.pyplot as plt

img_bgr = cv2.imread('me.jpeg')
plt.imshow(img_bgr)
plt.show()
color = ('b', 'g', 'r')
  
for i, col in enumerate(color):
      
    histr = cv2.calcHist([img_bgr], 
                         [i], None,
                         [256], 
                         [0, 256])
      
    plt.plot(histr, color = col)
    plt.xlim([0, 256])
      
plt.show()
height, width, _ = img_bgr.shape
  
for i in range(0, height - 1):
    for j in range(0, width - 1):
        pixel = img_bgr[i, j]
        pixel[0] = 255 - pixel[0]
        pixel[1] = 255 - pixel[1]
        pixel[2] = 255 - pixel[2]
        img_bgr[i, j] = pixel
plt.imshow(img_bgr)
plt.show()

color = ('b', 'g', 'r')
  
for i, col in enumerate(color):
      
    histr = cv2.calcHist([img_bgr], 
                         [i], None,
                         [256],
                         [0, 256])
      
    plt.plot(histr, color = col)
    plt.xlim([0, 256])
      
plt.show()

# %% [markdown]
# log transformation

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

i =cv2.imread('me.jpeg')
c = 255/ np.log(1+np.max(i))
log = c * (np.log(i+2))
log = np.array(log, dtype=np.uint8)
img3 = cv2.hconcat([i,log])
plt.imshow(img3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
i =cv2.imread('me.jpeg')
c = 255/ np.log(1+np.max(i))
log = c * (np.log(i+20))
log = np.array(log, dtype=np.uint8)
img3 = cv2.hconcat([i,log])
plt.imshow(img3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# gamma transformation

# %%
import numpy as np
import cv2
img = cv2.imread('me.jpeg')
gamma_two_point_two = np.array(255*(img/255)**2.2,dtype='uint8')
gamma_point_four = np.array(255*(img/255)**0.4,dtype='uint8')
img3 = cv2.hconcat([gamma_two_point_two,gamma_point_four])
plt.imshow(img3)
